# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import math

from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

PROJECT_DIR = "../"

plt.style.use('ggplot')

plt.rcParams["grid.alpha"] = 0.9
plt.rcParams["axes.facecolor"] = "#f0f0f0"
plt.rcParams["figure.facecolor"] = "#f0f0f0"
plt.rcParams["figure.figsize"] = (6.4*1.2, 4.8*1.2)

# %%
df = read_csv(PROJECT_DIR+"data/AirPassengers.csv", usecols=[1])

plt.plot(df)
plt.show()

# %% [markdown]
# Convert to numpy array and normalize.

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(df)

# %%
train_size = int(len(dataset) * .66)
test_size = len(dataset) - train_size

train, test = dataset[0:train_size,], dataset[train_size:len(dataset),]

# %% [markdown]
# Build training set using sequences with N values as input and N+1 as output.

# %%
def to_sequences(dataset, seq_size=1):
    x = []
    y = []
    
    for i in range(len(dataset)-seq_size-1):
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size, 0])
        
    return np.array(x), np.array(y)

# %% [markdown]
# Choose 5 days as length of the training sequence.

# %%
seq_size=5

train_X, train_y = to_sequences(train, seq_size)
test_X, test_y = to_sequences(test, seq_size)

# %%
print("Shape of training set: {}".format(train_X.shape))
print("Shape of testing set: {}".format(test_X.shape))
# Out:
# Shape of training set: (89, 5)
# Shape of testing set: (43, 5)

# %% [markdown]
# Build deep learning model.

# %%
model = keras.models.Sequential()

model.add(keras.layers.Dense(64, input_dim=seq_size, activation="relu"))
model.add(keras.layers.Dense(1))
model.compile(loss="mean_squared_error", optimizer="adam", metrics=["acc"])

print(model.summary())
# Out:
# WARNING:tensorflow:From /Users/carlosdavila/opt/anaconda3/envs/ts-forecasting/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                384
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 449
# Trainable params: 449
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Fit the model.

# %%
model.fit(train_X, train_y, validation_data=(test_X, test_y), verbose=2, epochs=100)
# Out:
# Train on 89 samples, validate on 43 samples
# Epoch 1/100
# 89/89 - 0s - loss: 0.0692 - acc: 0.0112 - val_loss: 0.3765 - val_acc: 0.0000e+00
# Epoch 2/100
# 89/89 - 0s - loss: 0.0543 - acc: 0.0112 - val_loss: 0.3040 - val_acc: 0.0000e+00
# Epoch 3/100
# 89/89 - 0s - loss: 0.0405 - acc: 0.0112 - val_loss: 0.2408 - val_acc: 0.0000e+00
# Epoch 4/100
# 89/89 - 0s - loss: 0.0295 - acc: 0.0112 - val_loss: 0.1860 - val_acc: 0.0000e+00
# Epoch 5/100
# 89/89 - 0s - loss: 0.0210 - acc: 0.0112 - val_loss: 0.1397 - val_acc: 0.0000e+00
# Epoch 6/100
# 89/89 - 0s - loss: 0.0141 - acc: 0.0112 - val_loss: 0.1026 - val_acc: 0.0000e+00
# Epoch 7/100
# 89/89 - 0s - loss: 0.0097 - acc: 0.0112 - val_loss: 0.0736 - val_acc: 0.0000e+00
# Epoch 8/100
# 89/89 - 0s - loss: 0.0066 - acc: 0.0112 - val_loss: 0.0529 - val_acc: 0.0233
# Epoch 9/100
# 89/89 - 0s - loss: 0.0056 - acc: 0.0112 - val_loss: 0.0385 - val_acc: 0.0233
# Epoch 10/100
# 89/89 - 0s - loss: 0.0055 - acc: 0.0112 - val_loss: 0.0294 - val_acc: 0.0233
# Epoch 11/100
# 89/89 - 0s - loss: 0.0056 - acc: 0.0112 - val_loss: 0.0246 - val_acc: 0.0233
# Epoch 12/100
# 89/89 - 0s - loss: 0.0057 - acc: 0.0112 - val_loss: 0.0225 - val_acc: 0.0233
# Epoch 13/100
# 89/89 - 0s - loss: 0.0024 - acc: 0.0112 - val_loss: 0.0125 - val_acc: 0.0233

# %% [markdown]
# Make predictions

# %%
train_pred = model.predict(train_X)
test_pred = model.predict(test_X)

# %% [markdown]
# Do the inverse of the min-max transformation to get the actual values.

# %%
train_pred = scaler.inverse_transform(train_pred)
train_y_inverse = scaler.inverse_transform([train_y])
test_pred = scaler.inverse_transform(test_pred)
test_y_inverse = scaler.inverse_transform([test_y])

# %% [markdown]
# Get the scores.

# %%
train_score = math.sqrt(mean_squared_error(train_y_inverse[0], train_pred[:,0]))
test_score = math.sqrt(mean_squared_error(test_y_inverse[0], test_pred[:,0]))

print("Train score: {:.2f} RMSE".format(train_score))
print("Test score: {:.2f} RMSE".format(test_score))
# Out:
# Train score: 25.21 RMSE
# Test score: 57.85 RMSE

# %% [markdown]
# The predictions are offset, so let's align them.

# %%
train_pred_aligned = np.empty_like(dataset)
train_pred_aligned[:, :] = np.nan
train_pred_aligned[seq_size:len(train_pred) + seq_size, :] = train_pred

# %%
test_pred_aligned = np.empty_like(dataset)
test_pred_aligned[:, :] = np.nan
test_pred_aligned[len(train_pred)+(seq_size*2)+1:len(dataset)-1, :] = test_pred

# %% [markdown]
# Finaly, plot the results.

# %%
plt.figure(figsize=(12,8))

plt.plot(scaler.inverse_transform(dataset))
plt.plot(train_pred_aligned)
plt.plot(test_pred_aligned)
plt.show()

# %% [markdown]
# Doesn't seem like a good prediction. Let's add one more layer to our model.

# %%
model = keras.models.Sequential()

model.add(keras.layers.Dense(64, input_dim=seq_size, activation="relu"))
model.add(keras.layers.Dense(32, activation="relu"))
model.add(keras.layers.Dense(1))
model.compile(loss="mean_squared_error", optimizer="adam", metrics=["acc"])

print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 64)                384
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 2,497
# Trainable params: 2,497
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Fit the model.

# %%
model.fit(train_X, train_y, validation_data=(test_X, test_y), verbose=0, epochs=100)

# %% [markdown]
# Make predictions

# %%
train_pred = model.predict(train_X)
test_pred = model.predict(test_X)

# %% [markdown]
# Do the inverse of the min-max transformation to get the actual values.

# %%
train_pred = scaler.inverse_transform(train_pred)
train_y_inverse = scaler.inverse_transform([train_y])
test_pred = scaler.inverse_transform(test_pred)
test_y_inverse = scaler.inverse_transform([test_y])

# %% [markdown]
# Get the scores.

# %%
train_score = math.sqrt(mean_squared_error(train_y_inverse[0], train_pred[:,0]))
test_score = math.sqrt(mean_squared_error(test_y_inverse[0], test_pred[:,0]))

print("Train score: {:.2f} RMSE".format(train_score))
print("Test score: {:.2f} RMSE".format(test_score))
# Out:
# Train score: 19.34 RMSE
# Test score: 42.24 RMSE

# %% [markdown]
# The predictions are offset, so let's align them.

# %%
train_pred_aligned = np.empty_like(dataset)
train_pred_aligned[:, :] = np.nan
train_pred_aligned[seq_size:len(train_pred) + seq_size, :] = train_pred

# %%
test_pred_aligned = np.empty_like(dataset)
test_pred_aligned[:, :] = np.nan
test_pred_aligned[len(train_pred)+(seq_size*2)+1:len(dataset)-1, :] = test_pred

# %% [markdown]
# Finaly, plot the results.

# %%
plt.figure(figsize=(12,8))

plt.plot(scaler.inverse_transform(dataset))
plt.plot(train_pred_aligned)
plt.plot(test_pred_aligned)
plt.show()

# %% [markdown]
# At least a bit better!
